# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

np.random.seed(50)

# %%
nsample = 100
x = np.linspace(0, 10, 100)
X = np.column_stack((x, x**2))
beta = np.array([1, 0.1, 10])
e = np.random.normal(0,50,size=nsample)

# %%
X = sm.add_constant(X)
y = np.dot(X, beta) + e

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     2026.
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           7.75e-80
# Time:                        06:35:08   Log-Likelihood:                -527.29
# No. Observations:                 100   AIC:                             1061.
# Df Residuals:                      97   BIC:                             1068.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.9254     14.089     -0.350      0.727     -32.888      23.037
# x1             2.6304      6.511      0.404      0.687     -10.293      15.554
# x2             9.8732      0.630     15.670      0.000       8.623      11.124
# ==============================================================================
# Omnibus:                        1.740   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.419   Jarque-Bera (JB):                1.366
# Skew:                           0.077   Prob(JB):                        0.505
# Kurtosis:                       2.448   Cond. No.                         144.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_true = np.dot(X, beta)

# %%
plt.scatter(x,y)

# %%
plt.plot(x, y, 'o', label="data")
plt.plot(x, y_true, 'b-', label="True")
plt.plot(x, results.fittedvalues, 'r--.', label="OLS")

# %%
groups = np.zeros(nsample, int)
groups[20:40] = 1
groups[40:] = 2
#dummy = (groups[:,None] == np.unique(groups)).astype(float)

dummy = pd.get_dummies(groups).values
x = np.linspace(0, 20, nsample)
# drop reference category
X = np.column_stack((x, dummy[:,1:]))
X = sm.add_constant(X)

beta = [10,1., 3, -3]
y_true = np.dot(X, beta)
e = np.random.normal(size=nsample)
y = y_true + e

# %%
plt.plot(x,y_true)

# %%
res2 = sm.OLS(y, X).fit()
print(res2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     667.4
# Date:                Sat, 19 Sep 2020   Prob (F-statistic):           3.87e-64
# Time:                        06:43:55   Log-Likelihood:                -139.25
# No. Observations:                 100   AIC:                             286.5
# Df Residuals:                      96   BIC:                             296.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.2682      0.232     44.183      0.000       9.807      10.730
# x1             0.9791      0.035     27.664      0.000       0.909       1.049
# x2             2.9954      0.345      8.674      0.000       2.310       3.681
# x3            -2.8443      0.500     -5.690      0.000      -3.837      -1.852
# ==============================================================================
# Omnibus:                        0.667   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.717   Jarque-Bera (JB):                0.705
# Skew:                          -0.189   Prob(JB):                        0.703
# Kurtosis:                       2.836   Cond. No.                         66.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
prstd, iv_l, iv_u = wls_prediction_std(res2)

fig, ax = plt.subplots(figsize=(8,6))

ax.plot(x, y, 'o', label="Data")
ax.plot(x, y_true, 'b-', label="True")
ax.plot(x, res2.fittedvalues, 'r--.', label="Predicted")
ax.plot(x, iv_u, 'r--')
ax.plot(x, iv_l, 'r--')
legend = ax.legend(loc="best")

# %%
R = [[0, 1, 0, 0], [0, 0, 1, 0]]
print(np.array(R))
print(res2.f_test(R))
# Out:
# [[0 1 0 0]
#  [0 0 1 0]]
# <F test: F=array([[627.189039]]), p=7.711892963634732e-56, df_denom=96, df_num=2>
